# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('telecom_churn.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
plt.figure(figsize=(5,10))
df["State"].value_counts().plot(kind="barh")
plt.xlabel("Count")
plt.ylabel("State")
plt.title("State Distribution")
plt.show()

# %%
df.groupby('Churn')['Account length'].mean()
# Out:
# Churn
# False    100.793684
# True     102.664596
# Name: Account length, dtype: float64

# %%
df.groupby('Area code')['Churn'].value_counts().unstack().plot(kind='bar')
plt.xlabel('Area Code')
plt.ylabel('Count')
plt.title('Area Code Distribution')
plt.show()
df.groupby('Area code')['Churn'].mean()
# Out:
# Area code
# 408    0.145585
# 415    0.142598
# 510    0.148810
# Name: Churn, dtype: float64

# %%
df['International plan'].value_counts(normalize=True)['Yes']*100
# Out:
# 9.69096909690969

# %%
df.groupby('International plan')['Churn'].mean()
# Out:
# International plan
# No     0.114950
# Yes    0.424149
# Name: Churn, dtype: float64

# %%
df['Voice mail plan'].value_counts(normalize=True)['Yes']*100
# Out:
# 27.662766276627664

# %%
print(df['Number vmail messages'].corr(df['Churn']))
# Out:
# -0.08972796983506436

# %%
df[['Total day minutes','Total eve minutes','Total night minutes']].mean()
# Out:
# Total day minutes      179.775098
# Total eve minutes      200.980348
# Total night minutes    200.872037
# dtype: float64

# %%
print(df['Total day minutes'].corr(df['Churn']))
# Out:
# 0.20515082926139028

# %%
print(df['Total day calls'].corr(df['Churn']))
# Out:
# 0.018459311608576896

# %%
df.groupby('Churn')['Total day charge'].mean()
# Out:
# Churn
# False    29.780421
# True     35.175921
# Name: Total day charge, dtype: float64

# %%
df.groupby('Churn')['Total eve minutes'].mean()
# Out:
# Churn
# False    199.043298
# True     212.410145
# Name: Total eve minutes, dtype: float64

# %%
df['Total eve minutes'].corr(df['Churn'])
# Out:
# 0.09279579031259165

# %%
# What impact does the total charge (sum of day, evening, night, and international) have on churn?
# How effective are the international and voice mail plans in retaining customers?

# %%
df.groupby('Churn')['Total night minutes'].mean()
# Out:
# Churn
# False    200.133193
# True     205.231677
# Name: Total night minutes, dtype: float64

# %%
df.groupby("Churn")["Total intl minutes"].mean()[True]
# Out:
# 10.700000000000001

# %%
print(df['Total intl calls'].corr(df['Churn']))
# Out:
# -0.05284433577413811

# %%
df.groupby('Churn')['Total intl charge'].mean()
# Out:
# Churn
# False    2.743404
# True     2.889545
# Name: Total intl charge, dtype: float64

# %%
df[df['Churn']==True]['Customer service calls'].count()
# Out:
# 483

# %%
df['Customer service calls'].corr(df['Churn'])
# Out:
# 0.20874999878379402

# %%
corr_matrix=df[['Total day minutes','Total day calls','Total eve minutes','Total eve calls','Total night minutes','Total night calls','Churn']].corr()
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
df[df['Churn']==True][['Total night calls','Total eve calls','Total day calls']].mean()
# Out:
# Total night calls    100.399586
# Total eve calls      100.561077
# Total day calls      101.335404
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
plt.figure(figsize=(10,10))
df.groupby('State')['Churn'].mean().plot(kind='barh')
plt.ylabel('State')
plt.xlabel('Count')
plt.title('State Distribution')
plt.show()

# %%
df['totale change']= df['Total day charge'] + df['Total eve charge'] + df['Total night charge'] + df['Total intl charge']
print(df.groupby('Churn')['totale change'].mean())
print(df['totale change'].corr(df['Churn']))
# Out:
# Churn
# False    58.448807
# True     65.355963
# Name: totale change, dtype: float64
# 0.23154867076808106

# %%
df.groupby(['International plan','Voice mail plan'])['Churn'].mean()
# Out:
# International plan  Voice mail plan
# No                  No                 0.138532
#                     Yes                0.053012
# Yes                 No                 0.437229
#                     Yes                0.391304
# Name: Churn, dtype: float64
